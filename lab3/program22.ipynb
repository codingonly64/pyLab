# %%
p_a = int(input("Enter the principal amount: "))
r_o_i = int(input("Enter the rate of interest: "))
time = int(input("Enter the time (in years): "))
c_i = p_a*((1 +(r_o_i/100))**time)
print("Compound interset is", c_i)
