# %%
# Define a function called square(number) that takes one argument, number, and returns the square
# of that number using the pow() function. Call this function with the argument 5 and print the
# result.

def square(number):
    return pow(number, 2)

result = square(5)
print(result)
# Out:
# 25
