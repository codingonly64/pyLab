# %%
# Define a function called max_of_three(a, b, c) that takes three numbers as input and 
# returns the largest of the three.
# The program should take user input for three numbers and call the function to display the maximum.

def max_of_three(a, b, c):
    return max(a, b, c)

a = float(input("Enter the first number: "))
b = float(input("Enter the second number: "))
c = float(input("Enter the third number: "))

print(f"The largest number is: {max_of_three(a, b, c)}")
