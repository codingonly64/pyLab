# %%
# Define a function called is_even(number) that returns True if the number is even and False if the
# number is odd. 
# The program should take user input for a number and call the function to display whether it's even or odd.

def is_even(number):
    return number % 2 == 0  # Returns True if even, False if odd

# Step 2: Get user input for the number
number = int(input("Enter a number: "))

# Step 3: Call the function and print whether it's even or odd
print(f"{number} {is even. if is_even(number) else is odd.}")
# Out:
#   Cell In[6], line 12
#     print(f"{number} {is even. if is_even(number) else is odd.}")
#                       ^
# SyntaxError: f-string: expecting a valid expression after '{'
