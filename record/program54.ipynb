# %%
import math
def perform_operation(n):
    square_root = math.sqrt(n)
    if n>=0:
        factorial = math.factorial(n)
    else:
        factorial = "undefined"
    pi_value = math.pi
    print("Square root of",n,"is",square_root)
    print("Value of Pie is",pi_value)

n = 5
perform_operation(n)
