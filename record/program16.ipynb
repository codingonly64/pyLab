# %%
num = int(input("Enter the number: "))
print("Multiplication for ", num)
print("-------------------------")
for i in range(1,11):
    print(i,"*",num,"=",i * num)
# Out:
# Enter the number:  4
# Multiplication for  4
# -------------------------
# 1 * 4 = 4
# 2 * 4 = 8
# 3 * 4 = 12
# 4 * 4 = 16
# 5 * 4 = 20
# 6 * 4 = 24
# 7 * 4 = 28
# 8 * 4 = 32
# 9 * 4 = 36
# 10 * 4 = 40
