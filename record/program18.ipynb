# %%
num = int(input("Enter the number: "))
for i in range(num,-1,-1):
    print(f"{("  ")*(num-i)}{("* ") *i}")
# Out:
# Enter the number:  5
# * * * * *
#   * * * *
#     * * *
#       * *
#         *
