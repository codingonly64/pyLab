# %%
base :float = float(input("Enter the base of the triangle"))
height :float = float(input("Enter the height of triangle"))
area = 0.5*base*height
print(f" area of triangle with base {base} and height {height} is {area}")
# Out:
# Enter the base of the triangle 53
# Enter the height of triangle 24
#  area of triangle with base 53.0 and height 24.0 is 636.0
