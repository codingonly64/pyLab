# %%
num1 :int = 199
num2 :int = 20523
sm :int = num1 + num2
print(f"The sum of {num1} and {num2} is {sm}")
# Out:
# The sum of 199 and 20523 is 20722

# %%
num1 :int = int(input("Enter the first number:"))
num2 :int = int(input("Enter the second number:"))
sm:int = num1 + num2
print(f"The sum of {num1} and {num2} is {sm}")
# Out:
# Enter the first number: 19
# Enter the second number: 325
# The sum of 19 and 325 is 344
