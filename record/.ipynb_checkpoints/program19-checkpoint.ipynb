# %%
num = int(input("Enter the number: "))
for i in range(1,num+1):
    print('  ' * (num - i) + (str((i-1) * 2) + ' ') * (i))
# Out:
# Enter the number:  5
#         0
#       2 2
#     4 4 4
#   6 6 6 6
# 8 8 8 8 8

# %%
        0
      2 2
    4 4 4
  6 6 6 6
8 8 8 8 8
