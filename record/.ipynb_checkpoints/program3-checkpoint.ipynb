# %%
input_str :str = input("Enter the string")
first_str :str = input_str[0]
modified_str :str = first_str + input_str[1:].replace(first_str,"$")
print("Modified string", modified_str)
# Out:
# Enter the string return
# Modified string retu$n
