# %%
words = input("Enter the string: ")
list_word = words.split()
large = 0
for i in list_word:
    if large<len(i):
        large = len(i)
print("Length of the longest word is ",large)
# Out:
# Enter the string:  hello world
# Length of the longest word is  5
