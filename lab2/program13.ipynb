# %%
# Create a program to convert a distance entered in kilometers to miles
km = float(input("Enter the distance in km:"))
mile = km * 0.621371
print(f"The miles traveled in {km} km is {mile}")
# Out:
# Enter the distance in km: 4929
# The miles traveled in 4929.0 km is 3062.737659
