# %%
# Write a program that calculates the area and perimeter of a rectangle based on user‐provided
# length and width.
length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the breadth of the rectangle: "))
area = length * width
print(f"Area of the rectangle is {area}")
# Out:
# Enter the length of the rectangle:  20
# Enter the breadth of the rectangle:  30
# Area of the rectangle is 600.0
