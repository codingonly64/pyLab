# %%
# Create a program that takes the first name and last name as input from the user and prints the
# full name

first_name = input("Enter the first name: ")
last_name = input("Enter the last name: ")
full_name = first_name +' '+last_name
print(f"The full name of the user is {full_name}")
# Out:
# Enter the first name:  sam
# Enter the last name:  novel
# The full name of the user is sam novel
