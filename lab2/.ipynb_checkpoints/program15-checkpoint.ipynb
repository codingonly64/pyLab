# %%
# Create a program that calculates the volume of a cube given its side length.
length = float(input("Enter the length of the cube: "))
volume = length ** 3
print(f"Volume of the cube is {volume}")
