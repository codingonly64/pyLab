# %%
# Write a program to compute the average of three numbers provided by the user
num1 = int(input("Enter the first number:"))
num2 = int(input("Enter the second number:"))
num3 = int(input("Enter the third number:"))
avg : float = (num1+num2+num3)/3
print(f"Average of the numbers {num1}, {num2}, {num3} is {(avg):.2f}")
# Out:
# Enter the first number: 20
# Enter the second number: 19
# Enter the third number: 35
# Average of the numbers 20, 19, 35 is 24.67
