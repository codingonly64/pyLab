# %%
# Create a program that converts a temperature entered in Celsius to Fahrenheit
celsius = float(input("Enter the temperature in celsius: "))
fahrenheit = (celsius * 1.8) + 32
print(f"Fahrenheit of the temperature {celsius} C is {fahrenheit} F")
# Out:
# Enter the temperature in celsius:  32
# Fahrenheit of the temperature 32.0 C is 89.6 F
